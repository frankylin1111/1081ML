# %% [markdown]
# # Homework3

# %% [markdown]
# 1. 身體質量指數(Body mass index, BMI)是由體重(公斤)除以身高(公尺)的平方，BMI 的分級如下。請撰寫程式由使用者輸入其體重(公斤)及身高(公分)，然後程式印出分級。(分級方式請參閱簡報)

# %%
   import math
a = eval(input("請輸入身高:"))
b = eval(input("請輸入體重:"))
    
c = b / ((a/100)**2)
if c >= 35:
    print("重度肥胖")
elif c >= 30:
    print("中度肥胖")
elif c >=27:
    print("輕度肥胖")
elif c > 24:
    print("體重過重")
elif c >= 18.5:
    print("正常範圍")
else:
    print("體重過輕")

# %% [markdown]
# 2. 閏年(Leap year)比平年(365 天)多一天，亦即 366 天。判斷閏年的方式如下(任一條件符合均可)：能被 4 整除但不能被 100 整除者/能被 400 整除者。請撰寫一程式，由使用者輸入西元年，程式判斷是否為閏年。

# %%
a = eval(input("請輸入年份:"))
if ((a%4)==0 and (a%100) !=0) or (a%400) == 0:
    print("是閏年")
else:
    print("是平年")

# %% [markdown]
# 3. 請撰寫一個程式，接受使用者輸入日期，格式為 mm/dd/yyyy (month, day, year)，程式判斷該日期是否正確。例如：09/31/2011 錯誤，因為 9 月只有 30 天；02/29/2011 錯誤，因為 2011 並非閏年。

# %%
a = input("請輸入日期:")
find =0
if int(a[:2])>12 or int(a[:2])<1:
    find =1
elif int(a[:2]) == 2:
    if ((int(a[6:])%4)!=0 or (int(a[6:])%100) ==0) and (int(a[6:])%400) != 0:
        if int(a[3:5]) == 29:
            find =1


elif int(a[:2]) == 4 and  int(a[:2]) == 6 and int(a[:2]) == 9 and int(a[:2]) == 11:
    if int(a[3:5]) == 31:
        find =1



if find ==1:
    print("格式錯誤!!")
else:
    print("格式正確!!")

# %% [markdown]
# 4. 如果任何大於 2 的正整數 n 為質數，則任何整數 m，2 ≤ m ≤ √𝑛 ，都無法整除 n。請撰寫一程式，由使用者輸入 n，程式判斷其是否為質數。

# %%
import math
while 1:
    find =0
    a = int(input("請輸入一個大於 2 的正整數:"))
    if a <=2:
        break
    b = int(math.sqrt(a)+1)
    print(b)
    for i in range(2,b):
        if (a%i) == 0:
            find = 1
            break
    if find == 1:
        print("是質數!!")
    else:
        print("不是質數!!")

# %% [markdown]
# 5. 修改上述程式，列出所有小於或等於 n 的質數。

# %%
import math
x=int(input("請輸入1個整數:"))
total=0
s1=[]

for i in range(int (math.sqrt(x))+1,x+1):
    s1.append(i)

for a  in range(2,int (math.sqrt(x))+1):
    q=2
    find= 1
    while(a>q):
        if (a%q==0):
            find=0
            break
        else:
            if (q==2):
                q=q+1
            else:
                    q=q+2
    if (find==1):
        total=total+1
        print (a)
        for j in s1:
            if (j%a==0):
                s1.remove(j)
                

for k in s1:
    total=total+1
    print (k)

print ("共有:%d個"%(total))
